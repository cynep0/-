# %% [markdown]
# <a href="https://colab.research.google.com/github/cynep0/-/blob/main/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Markdown
#
#
# 1.   Новый пункт
# 2.   Новый пункт
#
# First column name  | Second column name
# -------------------|------------------
# Row 1, Col 1       | Row 1, Col 2
# Row 2, Col 1       | Row 2, Col 2
#
# [A link](https://www.google.com)
#
# ![image.png](data:image/png;base64,...)
#
# изменение
